# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Import Corpus

# %%
col_types = {'Id': 'int', 
             'OwnerUserId': 'float', 
             'CreationDate': 'str', 
             'ParentId': 'int', 
             'Score': 'int',
             'Title': 'str',
             'Body':'str'}

questions = pd.read_csv('../pythonquestions/Questions.csv', encoding = "ISO-8859-1", dtype=col_types)
answers = pd.read_csv('../pythonquestions/Answers.csv', encoding = "ISO-8859-1", dtype=col_types)

# %%
questions.head(10)
# Out:
#      Id  OwnerUserId          CreationDate  Score  \
# 0   469        147.0  2008-08-02T15:11:16Z     21
# 1   502        147.0  2008-08-02T17:01:58Z     27
# 2   535        154.0  2008-08-02T18:43:54Z     40
# 3   594        116.0  2008-08-03T01:15:08Z     25
# 4   683        199.0  2008-08-03T13:19:16Z     28
# 5   742        189.0  2008-08-03T15:55:28Z     30
# 6   766    1384652.0  2008-08-03T17:44:07Z     20
# 7   773        207.0  2008-08-03T18:27:09Z    256
# 8   972        145.0  2008-08-04T02:17:51Z    364
# 9  1476         92.0  2008-08-04T18:20:36Z    251
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
# 5                              Class views in Django
# 6                                   Python and MySQL
# 7         How do I use Python's itertools.groupby()?
# 8     Adding a Method to an Existing Object Instance
# 9      How do you express binary literals in Python?
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...
# 5  <p><a href="http://www.djangoproject.com/">Dja...
# 6  <p>I can get Python to work with Postgresql bu...
# 7  <p>I haven't been able to find an understandab...
# 8  <p>I've read that it is possible to add a meth...
# 9  <p>How do you express an integer as a binary n...

# %%
answers.head(10)
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0  497         50.0  2008-08-02T16:56:53Z       469      4
# 1  518        153.0  2008-08-02T17:42:28Z       469      2
# 2  536        161.0  2008-08-02T18:49:07Z       502      9
# 3  538        156.0  2008-08-02T18:56:56Z       535     23
# 4  541        157.0  2008-08-02T19:06:40Z       535     20
# 5  595        116.0  2008-08-03T01:17:36Z       594     25
# 6  660        197.0  2008-08-03T12:09:18Z       535     14
# 7  701        111.0  2008-08-03T14:30:50Z       683      3
# 8  735        145.0  2008-08-03T15:47:22Z       683     -2
# 9  745        154.0  2008-08-03T15:59:19Z       683      8
#
#                                                 Body
# 0  <p>open up a terminal (Applications-&gt;Utilit...
# 1  <p>I haven't been able to find anything that d...
# 2  <p>You can use ImageMagick's convert utility f...
# 3  <p>One possibility is Hudson.  It's written in...
# 4  <p>We run <a href="http://buildbot.net/trac">B...
# 5  <p>The canonical way is to use the built-in cu...
# 6  <p>Second the Buildbot - Trac integration. You...
# 7  <p>No, you were not dreaming.  Python has a pr...
# 8  <p>I think:</p>\r\n\r\n<pre><code>#!/bin/pytho...
# 9  <p>Are you looking to get a list of objects th...

# %% [markdown]
# # Map Questions to Answers and Filter Questions w/ 4+ Answers

# %%
q_to_a = dict()
for ind, row in answers[['Id', 'ParentId', 'Score']].iterrows():
    qid = row['ParentId']
    aid = row['Id']
    a_score = row['Score']
    if qid not in q_to_a:
        q_to_a[qid] = [(aid, a_score)]
    else:
        q_to_a[qid].append((aid, a_score))

def focus(answer_list):
    if len(answer_list) < 4:
        return False
    
    for pair in answer_list:
        if pair[1] > 0:
            return True
    return False

q_to_a = {k:v for k, v in q_to_a.items() if focus(v)}

questions = questions[questions['Id'].isin(q_to_a)]

# %%
def answer_in_use(answer):
    if answer['ParentId'] in q_to_a:
        for item in q_to_a[answer['ParentId']]:
            if answer['Id'] == item[0]:
                return True
    return False

answers = answers[answers.apply(lambda x: answer_in_use(x), axis=1)]

# %%
questions['BodyText'] = questions['Body'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
answers['BodyText'] = answers['Body'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# %%
questions.head(10)
# Out:
#       Id  OwnerUserId          CreationDate  Score  \
# 0    469        147.0  2008-08-02T15:11:16Z     21
# 2    535        154.0  2008-08-02T18:43:54Z     40
# 4    683        199.0  2008-08-03T13:19:16Z     28
# 5    742        189.0  2008-08-03T15:55:28Z     30
# 6    766    1384652.0  2008-08-03T17:44:07Z     20
# 7    773        207.0  2008-08-03T18:27:09Z    256
# 8    972        145.0  2008-08-04T02:17:51Z    364
# 9   1476         92.0  2008-08-04T18:20:36Z    251
# 10  1734         59.0  2008-08-05T00:12:55Z     20
# 11  1829         30.0  2008-08-05T02:39:23Z     12
#
#                                                 Title  \
# 0   How can I find the full path to a font from it...
# 2   Continuous Integration System for a Python Cod...
# 4   Using 'in' to match an attribute of Python obj...
# 5                               Class views in Django
# 6                                    Python and MySQL
# 7          How do I use Python's itertools.groupby()?
# 8      Adding a Method to an Existing Object Instance
# 9       How do you express binary literals in Python?
# 10             Any experiences with Protocol Buffers?
# 11  How do I make a menu that does not require the...
#
#                                                  Body  \
# 0   <p>I am using the Photoshop's javascript API t...
# 2   <p>I'm starting work on a hobby project with a...
# 4   <p>I don't remember whether I was dreaming or ...
# 5   <p><a href="http://www.djangoproject.com/">Dja...
# 6   <p>I can get Python to work with Postgresql bu...
# 7   <p>I haven't been able to find an understandab...
# 8   <p>I've read that it is possible to add a meth...
# 9   <p>How do you express an integer as a binary n...
# 10  <p>I was just looking through some information...
# 11  <p>I've got a menu in Python. That part was ea...
#
#                                              BodyText
# 0   I am using the Photoshop's javascript API to f...
# 2   I'm starting work on a hobby project with a py...
# 4   I don't remember whether I was dreaming or not...
# 5   Django view points to a function, which can be...
# 6   I can get Python to work with Postgresql but I...
# 7   I haven't been able to find an understandable ...
# 8   I've read that it is possible to add a method ...
# 9   How do you express an integer as a binary numb...
# 10  I was just looking through some information ab...
# 11  I've got a menu in Python. That part was easy....

# %%
answers.head(10)
# Out:
#      Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0   497         50.0  2008-08-02T16:56:53Z       469      4
# 1   518        153.0  2008-08-02T17:42:28Z       469      2
# 3   538        156.0  2008-08-02T18:56:56Z       535     23
# 4   541        157.0  2008-08-02T19:06:40Z       535     20
# 6   660        197.0  2008-08-03T12:09:18Z       535     14
# 7   701        111.0  2008-08-03T14:30:50Z       683      3
# 8   735        145.0  2008-08-03T15:47:22Z       683     -2
# 9   745        154.0  2008-08-03T15:59:19Z       683      8
# 10  750        199.0  2008-08-03T16:13:29Z       683      2
# 11  764          NaN  2008-08-03T17:40:25Z       742      0
#
#                                                  Body  \
# 0   <p>open up a terminal (Applications-&gt;Utilit...
# 1   <p>I haven't been able to find anything that d...
# 3   <p>One possibility is Hudson.  It's written in...
# 4   <p>We run <a href="http://buildbot.net/trac">B...
# 6   <p>Second the Buildbot - Trac integration. You...
# 7   <p>No, you were not dreaming.  Python has a pr...
# 8   <p>I think:</p>\r\n\r\n<pre><code>#!/bin/pytho...
# 9   <p>Are you looking to get a list of objects th...
# 10  <p>What I was thinking of can be achieved usin...
# 11  <p>Sounds to me like you're trying to combine ...
#
#                                              BodyText
# 0   open up a terminal (Applications->Utilities->T...
# 1   I haven't been able to find anything that does...
# 3   One possibility is Hudson.  It's written in Ja...
# 4   We run Buildbot - Trac at work, I haven't used...
# 6   Second the Buildbot - Trac integration. You ca...
# 7   No, you were not dreaming.  Python has a prett...
# 8   I think:\n#!/bin/pythonbar in dict(Foo)\nIs wh...
# 9   Are you looking to get a list of objects that ...
# 10  What I was thinking of can be achieved using l...
# 11  Sounds to me like you're trying to combine thi...

# %% [markdown]
# # Answers: Count English Words, Number of Links, and Does it Have Code?

# %%
def strip_code(html):
    bs = BeautifulSoup(html, 'html.parser')
    [s.extract() for s in bs('code')]
    return bs.get_text()

def count_links(html):
    bs = BeautifulSoup(html, 'html.parser')
    return len(bs.find_all('a'))

def has_code(html):
    bs = BeautifulSoup(html, 'html.parser')
    return 1 if bs.find('code') != None else 0
    
answers['BodyEnglishText'] = answers['Body'].apply(strip_code)
answers['EnglishCount'] = answers['BodyEnglishText'].apply(lambda x: len(x.split()))
answers['LinkCount'] = answers['Body'].apply(count_links)
answers['HasCode'] = answers['Body'].apply(has_code)

# %%
answers.head(10)
# Out:
#      Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0   497         50.0  2008-08-02T16:56:53Z       469      4
# 1   518        153.0  2008-08-02T17:42:28Z       469      2
# 3   538        156.0  2008-08-02T18:56:56Z       535     23
# 4   541        157.0  2008-08-02T19:06:40Z       535     20
# 6   660        197.0  2008-08-03T12:09:18Z       535     14
# 7   701        111.0  2008-08-03T14:30:50Z       683      3
# 8   735        145.0  2008-08-03T15:47:22Z       683     -2
# 9   745        154.0  2008-08-03T15:59:19Z       683      8
# 10  750        199.0  2008-08-03T16:13:29Z       683      2
# 11  764          NaN  2008-08-03T17:40:25Z       742      0
#
#                                                  Body  \
# 0   <p>open up a terminal (Applications-&gt;Utilit...
# 1   <p>I haven't been able to find anything that d...
# 3   <p>One possibility is Hudson.  It's written in...
# 4   <p>We run <a href="http://buildbot.net/trac">B...
# 6   <p>Second the Buildbot - Trac integration. You...
# 7   <p>No, you were not dreaming.  Python has a pr...
# 8   <p>I think:</p>\r\n\r\n<pre><code>#!/bin/pytho...
# 9   <p>Are you looking to get a list of objects th...
# 10  <p>What I was thinking of can be achieved usin...
# 11  <p>Sounds to me like you're trying to combine ...
#
#                                              BodyText  \
# 0   open up a terminal (Applications->Utilities->T...
# 1   I haven't been able to find anything that does...
# 3   One possibility is Hudson.  It's written in Ja...
# 4   We run Buildbot - Trac at work, I haven't used...
# 6   Second the Buildbot - Trac integration. You ca...
# 7   No, you were not dreaming.  Python has a prett...
# 8   I think:\n#!/bin/pythonbar in dict(Foo)\nIs wh...
# 9   Are you looking to get a list of objects that ...
# 10  What I was thinking of can be achieved using l...
# 11  Sounds to me like you're trying to combine thi...
#
#                                       BodyEnglishText  EnglishCount  \
# 0   open up a terminal (Applications->Utilities->T...            29
# 1   I haven't been able to find anything that does...            38
# 3   One possibility is Hudson.  It's written in Ja...            36
# 4   We run Buildbot - Trac at work, I haven't used...            42
# 6   Second the Buildbot - Trac integration. You ca...           144
# 7   No, you were not dreaming.  Python has a prett...           157
# 8   I think:\n\nIs what you are thinking of.  When...           235
# 9   Are you looking to get a list of objects that ...            26
# 10  What I was thinking of can be achieved using l...            59
# 11  Sounds to me like you're trying to combine thi...            75
#
#     LinkCount  HasCode
# 0           0        1
# 1           0        1
# 3           2        0
# 4           1        0
# 6           1        0
# 7           1        1
# 8           2        1
# 9           1        1
# 10          0        1
# 11          0        0
